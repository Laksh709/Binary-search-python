# %%
def locate_card(cards,query):
    pass

# %%
cards = [ 13,11,12,7,4,3,1,0]
query = 7
output = 3

# %%
result = locate_card(cards,query)
print(result)
# Out:
# None

# %%
result == output
# Out:
# False

# %%
test = {
    'input': {
        'cards' : [13,11,12,7,4,3,1,0],
        'query' : 7
},
        'output': 3 
}

# %%
locate_card(**test['input']) == test['output']
# Out:
# False

# %%
tests = []

# %%
tests.append(test)
#cards contain query in the middle
tests.append({
    'input': {
        'cards' : [13,11,12,7,4,3,1,0],
        'query' : 1
},
        'output': 6
})

# %%
#cards contain query as the first element
tests.append({
    'input': {
        'cards' : [4,2,1,-1],
        'query' : 4
},
        'output': 0
})

# %%
#cards contain only one element ,that is query itself
tests.append({
    'input': {
        'cards' : [6],
        'query' : 6
},
        'output': 0
})

# %%
#cards contain query at the end of the list
tests.append({
    'input': {
        'cards' : [3,-1,-9,-127],
        'query' : -127
},
        'output': 3
})

# %%
#cards does not contain the carry abd we assumne -1 to be the output in all such cases 
tests.append({
    'input': {
        'cards' : [9,7,5,2,-9],
        'query' : 4
},
        'output': -1
})

# %%
#cards is empty
tests.append({
    'input': {
        'cards' : [],
        'query' : 4
},
        'output': -1
})

# %%
tests.append({
    'input': {
        'cards' : [9,7,5,2,-9],
        'query' : 4
},
        'output': -1
})

# %%
#query can occur multiple times , we expect the function to return the position of the first query
tests.append({
    'input': {
        'cards' : [8,8,6,6,6,6,6,6,2,2,2,1,1],
        'query' : 6
},
        'output': 2
})

# %%
tests
# Out:
# [{'input': {'cards': [13, 11, 12, 7, 4, 3, 1, 0], 'query': 7}, 'output': 3},
#  {'input': {'cards': [13, 11, 12, 7, 4, 3, 1, 0], 'query': 1}, 'output': 6},
#  {'input': {'cards': [4, 2, 1, -1], 'query': 4}, 'output': 0},
#  {'input': {'cards': [6], 'query': 6}, 'output': 0},
#  {'input': {'cards': [3, -1, -9, -127], 'query': -127}, 'output': 3},
#  {'input': {'cards': [9, 7, 5, 2, -9], 'query': 4}, 'output': -1},
#  {'input': {'cards': [], 'query': 4}, 'output': -1},
#  {'input': {'cards': [9, 7, 5, 2, -9], 'query': 4}, 'output': -1},
#  {'input': {'cards': [8, 8, 6, 6, 6, 6, 6, 6, 2, 2, 2, 1, 1], 'query': 6},
#   'output': 2}]

# %%
def locate_card_linear(cards, query):
    position = 0 
    
    while True :
       if cards[position] == query:
        return position 

       position += 1

       if position == len(cards):
            return -1

# %%
test
# Out:
# {'input': {'cards': [13, 11, 12, 7, 4, 3, 1, 0], 'query': 7}, 'output': 3}

# %%
result = locate_card(test['input']['cards'] , test['input']['query'])
result

# %%
result == output
# Out:
# False

# %%
# !pip install jovian --upgrade --quiet

# %%
from jovian.pythondsa import evaluate_test_case

# %%
evaluate_test_case(locate_card , test)
# Out:
# Input:
# {'cards': [13, 11, 12, 7, 4, 3, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# None
#
# Execution Time:
# 0.003 ms
#
# Test Result:
# FAILED
# (None, False, 0.003)

# %%
from jovian.pythondsa import evaluate_test_cases

# %%
evaluate_test_cases(locate_card , tests)
# Out:
# TEST CASE #0
#
# Input:
# {'cards': [13, 11, 12, 7, 4, 3, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# None
#
# Execution Time:
# 0.003 ms
#
# Test Result:
# FAILED
#
#
# TEST CASE #1
#
# Input:
# {'cards': [13, 11, 12, 7, 4, 3, 1, 0], 'query': 1}
#
# Expected Output:
# 6
#
#
# Actual Output:
# None
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# FAILED
#
#
# TEST CASE #2
#
# Input:
# {'cards': [4, 2, 1, -1], 'query': 4}
#
# Expected Output:
# 0
#
#
# Actual Output:
# None
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# FAILED
#
#
# TEST CASE #3
#
# Input:
# {'cards': [6], 'query': 6}
#
# Expected Output:
# 0
#
#
# Actual Output:
# None
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# FAILED
#
#
# TEST CASE #4
#
# Input:
# {'cards': [3, -1, -9, -127], 'query': -127}
#
# Expected Output:
# 3
#
#
# Actual Output:
# None
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# FAILED
#
#
# TEST CASE #5
#
# Input:
# {'cards': [9, 7, 5, 2, -9], 'query': 4}
#
# Expected Output:
# -1
#
#
# Actual Output:
# None
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# FAILED
#
#
# TEST CASE #6
#
# Input:
# {'cards': [], 'query': 4}
#
# Expected Output:
# -1
#
#
# Actual Output:
# None
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# FAILED
#
#
# TEST CASE #7
#
# Input:
# {'cards': [9, 7, 5, 2, -9], 'query': 4}
#
# Expected Output:
# -1
#
#
# Actual Output:
# None
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# FAILED
#
#
# TEST CASE #8
#
# Input:
# {'cards': [8, 8, 6, 6, 6, 6, 6, 6, 2, 2, 2, 1, 1], 'query': 6}
#
# Expected Output:
# 2
#
#
# Actual Output:
# None
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# FAILED
#
#
# SUMMARY
#
# TOTAL: 9, PASSED: 0, FAILED: 9
# [(None, False, 0.003),
#  (None, False, 0.002),
#  (None, False, 0.002),
#  (None, False, 0.002),
#  (None, False, 0.002),
#  (None, False, 0.002),
#  (None, False, 0.002),
#  (None, False, 0.001),
#  (None, False, 0.001)]

# %%
def locate_card_linear(cards, query):
    position = 0 
    print('cards:',cards)
    print('query:',query)
    
    while True :
        print('position:',position)
        
        if cards[position]==query:
            return position
        

        position += 1
        if position == len(cards):
            return -1

# %%
cards6 = tests[6]['input']['cards']
query6 = tests[6]['input']['query']
locate_card(cards6,query6)

# %%
def locate_card_linear(cards, query):
    position = 0

    while position<len(cards) :
        if cards[position] == query:
            return position
        position +=1
    return -1

# %%
tests[6]
# Out:
# {'input': {'cards': [], 'query': 4}, 'output': -1}

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Laksh\anaconda_projects\0e0825e4-2d38-4459-aa67-9187c8c65b1f

# %%
def locate_card(cards,query):
    lo,hi = 0,len(cards)-1
    while lo<=hi:
        mid = (lo+hi)//2
        mid_number = cards[mid]
        

        if mid_number == query:
            return mid
        elif mid_number< query:
            hi = mid - 1
            
        elif mid_number> query:
            lo = mid + 1
        

    return -1

# %%
evaluate_test_cases(locate_card,tests)
# Out:
# TEST CASE #0
#
# Input:
# {'cards': [13, 11, 12, 7, 4, 3, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.005 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'cards': [13, 11, 12, 7, 4, 3, 1, 0], 'query': 1}
#
# Expected Output:
# 6
#
#
# Actual Output:
# 6
#
# Execution Time:
# 0.006 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'cards': [4, 2, 1, -1], 'query': 4}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.004 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'cards': [6], 'query': 6}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'cards': [3, -1, -9, -127], 'query': -127}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.003 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
#
# Input:
# {'cards': [9, 7, 5, 2, -9], 'query': 4}
#
# Expected Output:
# -1
#
#
# Actual Output:
# -1
#
# Execution Time:
# 0.003 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #6
#
# Input:
# {'cards': [], 'query': 4}
#
# Expected Output:
# -1
#
#
# Actual Output:
# -1
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #7
#
# Input:
# {'cards': [9, 7, 5, 2, -9], 'query': 4}
#
# Expected Output:
# -1
#
#
# Actual Output:
# -1
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #8
#
# Input:
# {'cards': [8, 8, 6, 6, 6, 6, 6, 6, 2, 2, 2, 1, 1], 'query': 6}
#
# Expected Output:
# 2
#
#
# Actual Output:
# 6
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# FAILED
#
#
# SUMMARY
#
# TOTAL: 9, PASSED: 8, FAILED: 1
# [(3, True, 0.005),
#  (6, True, 0.006),
#  (0, True, 0.004),
#  (0, True, 0.002),
#  (3, True, 0.003),
#  (-1, True, 0.003),
#  (-1, True, 0.001),
#  (-1, True, 0.002),
#  (6, False, 0.002)]

# %%
def test_location(cards , query , mid):
    mid_number= cards[mid]
    if mid_number== query :
        if mid-1>=0 and cards[mid-1]==query:
            return 'left'
        else:
            return 'found'
    elif mid_number<query:
        return 'left'
    else:
        return 'right'

def locate_card(cards,query):
    lo,hi = 0,len(cards)-1
    while lo<=hi:
        
        
        mid = (lo+hi)//2
        result = test_location(cards , query , mid)

        if result == 'found':
            return mid
        elif result == 'left':
             hi =  mid-1
        elif result == 'right':
             lo =  mid+1
    return -1

# %%
evaluate_test_case(locate_card,tests[8])
# Out:
# Input:
# {'cards': [8, 8, 6, 6, 6, 6, 6, 6, 2, 2, 2, 1, 1], 'query': 6}
#
# Expected Output:
# 2
#
#
# Actual Output:
# 2
#
# Execution Time:
# 0.01 ms
#
# Test Result:
# PASSED
# (2, True, 0.01)

# %%
def locate_card_linear(cards, query):
    position = 0

    while position<len(cards) :
        if cards[position] == query:
            return position
        position +=1
    return -1

# %%
large_test = {
    'input': {
        'cards':list(range(10000000,0,-1)) ,
        'query': 2,
    } , 
    'output':9999998
}

# %%
result, passed, runtime = evaluate_test_case(locate_card_linear,large_test,display = False)
print("Result : {} \n Passed : {} \n Execution time : {} ms ".format(result,passed,runtime))
# Out:
# Result : 9999998
#  Passed : True
#  Execution time : 1145.005 ms

# %%
result, passed, runtime = evaluate_test_case(locate_card,large_test,display = False)
print("Result : {} \n Passed : {} \n Execution time : {} ms ".format(result,passed,runtime))
# Out:
# Result : 9999998
#  Passed : True
#  Execution time : 0.032 ms

# %%
def binary_search(lo,hi,condition):
    while lo<=hi:
        mid = (lo+hi)//2
        result =condition(mid)
        if result == 'found':
            return mid
        elif result == 'left':
            hi = mid - 1
        else:
            lo = mid +1 
    return -1

# %%
def locate_card(cards,query):

    def condition(mid):
        if cards[mid] == query:
            if  mid > 0 and cards[mid-1]== query:
                return 'left'
            else:
                return 'found'
        elif cards[mid] < query:
            return 'left'
        else:
            return 'right'
    
    return binary_search(0, len(cards)-1 , condition)

# %%
evaluate_test_cases(locate_card,tests)
# Out:
# TEST CASE #0
#
# Input:
# {'cards': [13, 11, 12, 7, 4, 3, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.025 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'cards': [13, 11, 12, 7, 4, 3, 1, 0], 'query': 1}
#
# Expected Output:
# 6
#
#
# Actual Output:
# 6
#
# Execution Time:
# 0.013 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'cards': [4, 2, 1, -1], 'query': 4}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.006 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'cards': [6], 'query': 6}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.004 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'cards': [3, -1, -9, -127], 'query': -127}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.005 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
#
# Input:
# {'cards': [9, 7, 5, 2, -9], 'query': 4}
#
# Expected Output:
# -1
#
#
# Actual Output:
# -1
#
# Execution Time:
# 0.006 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #6
#
# Input:
# {'cards': [], 'query': 4}
#
# Expected Output:
# -1
#
#
# Actual Output:
# -1
#
# Execution Time:
# 0.003 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #7
#
# Input:
# {'cards': [9, 7, 5, 2, -9], 'query': 4}
#
# Expected Output:
# -1
#
#
# Actual Output:
# -1
#
# Execution Time:
# 0.004 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #8
#
# Input:
# {'cards': [8, 8, 6, 6, 6, 6, 6, 6, 2, 2, 2, 1, 1], 'query': 6}
#
# Expected Output:
# 2
#
#
# Actual Output:
# 2
#
# Execution Time:
# 0.005 ms
#
# Test Result:
# PASSED
#
#
# SUMMARY
#
# TOTAL: 9, PASSED: 9, FAILED: 0
# [(3, True, 0.025),
#  (6, True, 0.013),
#  (0, True, 0.006),
#  (0, True, 0.004),
#  (3, True, 0.005),
#  (-1, True, 0.006),
#  (-1, True, 0.003),
#  (-1, True, 0.004),
#  (2, True, 0.005)]
